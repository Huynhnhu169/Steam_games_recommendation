# %% [markdown]
# # Leakage-Safe Modeling
#
# This notebook delegates modeling to the `src/` pipeline. The pipeline splits interactions before building user-item matrices or computing similarity.

# %%
from pathlib import Path
import os
import sys

ROOT = Path.cwd()
if ROOT.name == 'notebooks':
    ROOT = ROOT.parent
os.chdir(ROOT)
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from src.data import load_config
from src.train import build_train_test

config = load_config('configs/recommender.yaml')
interactions, catalog, train, test = build_train_test(config)
len(interactions), len(train), len(test)

# %%
# Terminal commands:
# python -m src.train --config configs/recommender.yaml
# python -m src.evaluate --config configs/recommender.yaml
# python -m src.recommend --config configs/recommender.yaml --game "Counter-Strike 2" --top-k 10
