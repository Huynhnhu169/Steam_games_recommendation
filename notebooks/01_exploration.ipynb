# %% [markdown]
# # Dataset Exploration
#
# Lightweight checks for the Steam reviews and games metadata. Reusable logic lives in `src/`.

# %%
from pathlib import Path
import os
import sys

ROOT = Path.cwd()
if ROOT.name == 'notebooks':
    ROOT = ROOT.parent
os.chdir(ROOT)
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from src.data import load_config, load_raw_data
from src.preprocess import prepare_interactions

config = load_config('configs/recommender.yaml')
reviews, games = load_raw_data(config)
interactions, catalog = prepare_interactions(reviews, games, config)

reviews.shape, games.shape, interactions.shape, catalog.shape

# %%
interactions['user_id'].nunique(), interactions['item_id'].nunique()
